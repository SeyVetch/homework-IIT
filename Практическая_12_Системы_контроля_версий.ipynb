# %% [markdown]
# # Титульный лист

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по практической работе № 12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«Система контроля версий»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2305 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Маханов Александр Анатольевич </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание

# %% [markdown]
# [1. Постановка задач](#Постановка_задач)
#
# [1.1. Задание](#Задание)
#
# [1.2. Цель работы](#Цель_работы)
#
# [1.3. Задачи работы](#Задачи_работы)
#
# [1.4. Расчет входных данных](#Расчет_входных_данных)
#
# [2. Ход работы](#Ход_работы)
#
# [3. Результат выполнения работы](#Результат)
#
# [4. Контрольное задание на защиту](#Конт_задание)

# %% [markdown]
# # Постановка задач
# <a name = "Постановка_задач">

# %% [markdown]
# > ## <a name = "Задание">Задание</a>
#
# 1. Установить GIT.
#
# 2. Создать локальный репозиторий.
#
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#
# 4. Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
#
# 5. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
#
# 6. Слейте последнее изменение отчета в основную ветку.
#
# 7. Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
#
# 8. Слейте последнее изменение отчета в основную ветку.
#
# 9. Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект.
#
# 10. Разместить на github ранее созданный статический сайт.
#
# 11. Доп. задание – Разметить на github ранее созданный динамический сайт.

# %% [markdown]
# ## <a name = "Цель_работы">Цель работы</a>
#
# Репозитории на гитхаб

# %% [markdown]
# ## <a name = "Задачи_работы">Задачи работы</a>
#
#
# 1. Установить гит
# 2. создать локальный репохиторий
# 3. Создать файл отчета и поместить в репозиторий
# 4. Зафиксировать проделаные шаги в отчёте
# 5. Создать коммит отчета в локальном репозитории
# 6. Создать новую ветку и поместить туда текущую версию отчета

# %% [markdown]
# ## <a name = "Расчет_входных_данных">Расчет входных данных</a>
#
# Гит, аккаунт Гитхаб, статический и динамический сайты из предыдущих практических работ

# %% [markdown]
# # <a name = "Ход_работы">Ход работы </a>
#
# 1. Я установил гит
# 2. Я создал локальный репозиторий
# 3. Создал этот отчёт и поместил его в репозиторий
# 4. Я закомитил отчет
# 5. Я создал новую ветку и поместил туда текущий отчет

# %% [markdown]
# # <a name = "Результат">Результат выполнения работы</a>

# %% [markdown]
# # <a name = "Конт_задание">Контрольное задание</a>
